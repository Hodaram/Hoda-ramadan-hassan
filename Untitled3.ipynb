# %% [markdown]
# <a href="https://colab.research.google.com/github/Hodaram/Hoda-ramadan-hassan/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %% ── CELL 1 : Install & Import Libraries ──────────────────────────────────
# !pip install tensorflow scikit-learn matplotlib seaborn tqdm

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time, warnings
warnings.filterwarnings('ignore')

import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.metrics import (accuracy_score, precision_score, recall_score,
                              f1_score, confusion_matrix, classification_report)

print(f"TensorFlow : {tf.__version__}")
print(f"GPU        : {len(tf.config.list_physical_devices('GPU')) > 0}")
# Out:
# TensorFlow : 2.20.0
# GPU        : True

# %%
# %% ── CELL 2 : Load CIFAR-10 ───────────────────────────────────────────────
from tensorflow.keras.datasets import cifar10

CLASS_NAMES = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
NUM_CLASSES = 10

(X_train_raw, y_train_raw), (X_test_raw, y_test_raw) = cifar10.load_data()
y_train_raw = y_train_raw.flatten()
y_test_raw  = y_test_raw.flatten()

print(f"Train : {X_train_raw.shape}   |   Test : {X_test_raw.shape}")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 116s 1us/step
# Train : (50000, 32, 32, 3)   |   Test : (10000, 32, 32, 3)

# %%
# %% ── CELL 3 : Visualize Sample Images ─────────────────────────────────────
fig, axes = plt.subplots(2, 5, figsize=(14, 6))
fig.suptitle('CIFAR-10 – Sample Images (Original 32×32)', fontsize=15, fontweight='bold')

for i, ax in enumerate(axes.flat):
    idx = np.random.choice(np.where(y_train_raw == i)[0])
    ax.imshow(X_train_raw[idx])
    ax.set_title(CLASS_NAMES[i], fontsize=11)
    ax.axis('off')

plt.tight_layout()
plt.savefig('sample_images.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# %% ── CELL 4 : Preprocessing — Resize 32×32 → 224×224 + Normalize ──────────
TARGET_SIZE   = (224, 224)

# ⚠️ Colab Free  →  5000 / 1000
# Full dataset   →  change both to None
SUBSET_TRAIN  = 5000
SUBSET_TEST   = 1000

def resize_dataset(X, y, n_samples=None):
    if n_samples:
        idx = np.random.choice(len(X), n_samples, replace=False)
        X, y = X[idx], y[idx]
    X_resized = tf.image.resize(X, TARGET_SIZE).numpy()   # float32
    X_prep    = preprocess_input(X_resized)                # VGG16 normalization
    return X_prep, y

print("Resizing train …")
t0 = time.time()
X_train, y_train = resize_dataset(X_train_raw, y_train_raw, SUBSET_TRAIN)
print(f"  Done {time.time()-t0:.1f}s  |  shape: {X_train.shape}")

print("Resizing test …")
t0 = time.time()
X_test, y_test = resize_dataset(X_test_raw, y_test_raw, SUBSET_TEST)
print(f"  Done {time.time()-t0:.1f}s  |  shape: {X_test.shape}")
print(f"\n✅ Pixel range after preprocess_input : [{X_train.min():.1f}, {X_train.max():.1f}]")
# Out:
# Resizing train …
#   Done 6.1s  |  shape: (5000, 224, 224, 3)
# Resizing test …
#   Done 1.0s  |  shape: (1000, 224, 224, 3)
#
# ✅ Pixel range after preprocess_input : [-123.7, 151.1]

# %%
# %% ── CELL 5 : Train / Validation Split (80 / 20) ──────────────────────────
X_tr, X_val, y_tr, y_val = train_test_split(
    X_train, y_train,
    test_size=0.20, stratify=y_train, random_state=42
)

y_tr_oh   = to_categorical(y_tr,   NUM_CLASSES)
y_val_oh  = to_categorical(y_val,  NUM_CLASSES)
y_test_oh = to_categorical(y_test, NUM_CLASSES)

print(f"Train : {X_tr.shape[0]}  |  Val : {X_val.shape[0]}  |  Test : {X_test.shape[0]}")
# Out:
# Train : 4000  |  Val : 1000  |  Test : 1000

# %%
# %% ── CELL 6 : Data Augmentation ───────────────────────────────────────────
augmentor = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=0.1,
    fill_mode='nearest'
)

# Visualise augmented samples
fig, axes = plt.subplots(2, 5, figsize=(14, 6))
fig.suptitle('Augmented Samples (224×224)', fontsize=13, fontweight='bold')
sample_img = X_tr[:1]
aug_gen    = augmentor.flow(sample_img, batch_size=1)

for ax in axes.flat:
    img = next(aug_gen)[0]
    display = np.clip(img + [103.939, 116.779, 123.68], 0, 255).astype(np.uint8)
    ax.imshow(display[..., ::-1])   # BGR → RGB
    ax.axis('off')

plt.tight_layout()
plt.savefig('augmented_samples.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# %% ── CELL 7 : Load VGG16 Base ─────────────────────────────────────────────
vgg_base = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
vgg_base.summary()
print(f"\nVGG16 base parameters : {vgg_base.count_params():,}")


# %% ── CELL 8a : APPROACH 1 — VGG16 Feature Extraction ──────────────────────
feature_extractor = Model(inputs=vgg_base.input, outputs=vgg_base.output)
feature_extractor.trainable = False

def extract_features(X, model, batch_size=32):
    features = []
    for i in range(0, len(X), batch_size):
        batch = X[i:i+batch_size]
        feat  = model.predict(batch, verbose=0)
        feat  = feat.reshape(feat.shape[0], -1)   # flatten 7×7×512 = 25 088
        features.append(feat)
    return np.vstack(features)

print("Extracting features — train …")
t0 = time.time()
X_tr_feat   = extract_features(X_tr,   feature_extractor)
print(f"  {time.time()-t0:.1f}s  |  shape: {X_tr_feat.shape}")

print("Extracting features — val …")
X_val_feat  = extract_features(X_val,  feature_extractor)

print("Extracting features — test …")
X_test_feat = extract_features(X_test, feature_extractor)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)
# VGG16 base parameters : 14,714,688
# Extracting features — train …
#   64.5s  |  shape: (4000, 25088)
# Extracting features — val …
# Extracting features — test …

# %%
# %% ── CELL 8b : Scale + PCA ─────────────────────────────────────────────────
scaler = StandardScaler()
X_tr_scaled   = scaler.fit_transform(X_tr_feat)
X_val_scaled  = scaler.transform(X_val_feat)
X_test_scaled = scaler.transform(X_test_feat)

pca = PCA(n_components=0.95, random_state=42)
X_tr_pca   = pca.fit_transform(X_tr_scaled)
X_val_pca  = pca.transform(X_val_scaled)
X_test_pca = pca.transform(X_test_scaled)

print(f"PCA components : {X_tr_pca.shape[1]}  "
      f"({pca.explained_variance_ratio_.sum()*100:.1f}% variance retained)")
# Out:
# PCA components : 2957  (95.0% variance retained)

# %%
# %% ── CELL 8c : Train SVM Classifier ────────────────────────────────────────
SVM_KERNEL = 'linear'
SVM_C      = 1.0

svm_clf = SVC(kernel=SVM_KERNEL, C=SVM_C, random_state=42)
print(f"Training SVM (kernel={SVM_KERNEL}, C={SVM_C}) …")
t0 = time.time()
svm_clf.fit(X_tr_pca, y_tr)
svm_train_time = time.time() - t0
print(f"  Done in {svm_train_time:.1f}s")

y_pred_svm = svm_clf.predict(X_test_pca)
acc_svm    = accuracy_score(y_test, y_pred_svm)
prec_svm   = precision_score(y_test, y_pred_svm, average='macro')
rec_svm    = recall_score(y_test, y_pred_svm, average='macro')
f1_svm     = f1_score(y_test, y_pred_svm, average='macro')
cm_svm     = confusion_matrix(y_test, y_pred_svm)

print(f"\n── Approach 1 (VGG16 + SVM) ──────────────────")
print(f"  Accuracy  : {acc_svm*100:.2f}%")
print(f"  Precision : {prec_svm*100:.2f}%")
print(f"  Recall    : {rec_svm*100:.2f}%")
print(f"  F1-Score  : {f1_svm*100:.2f}%")
print(f"  Time      : {svm_train_time:.1f}s")
# Out:
# Training SVM (kernel=linear, C=1.0) …
#   Done in 18.3s
#
# ── Approach 1 (VGG16 + SVM) ──────────────────
#   Accuracy  : 80.20%
#   Precision : 80.49%
#   Recall    : 80.38%
#   F1-Score  : 80.23%
#   Time      : 18.3s

# %%
# %% ── CELL 8d : Confusion Matrix — Approach 1 ───────────────────────────────
plt.figure(figsize=(10, 8))
sns.heatmap(cm_svm, annot=True, fmt='d', cmap='Blues',
            xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES)
plt.title('Confusion Matrix – Approach 1: VGG16 + SVM', fontsize=13, fontweight='bold')
plt.xlabel('Predicted'); plt.ylabel('True')
plt.tight_layout()
plt.savefig('cm_approach1_svm.png', dpi=150, bbox_inches='tight')
plt.show()
print(classification_report(y_test, y_pred_svm, target_names=CLASS_NAMES))
# Out:
#               precision    recall  f1-score   support
#
#     airplane       0.79      0.89      0.84        91
#   automobile       0.93      0.89      0.91        99
#         bird       0.79      0.68      0.73        93
#          cat       0.58      0.64      0.61        99
#         deer       0.79      0.77      0.78       115
#          dog       0.75      0.68      0.71       104
#         frog       0.74      0.90      0.81        90
#        horse       0.88      0.82      0.85       107
#         ship       0.92      0.88      0.89       112
#        truck       0.90      0.90      0.90        90
#
#     accuracy                           0.80      1000
#    macro avg       0.80      0.80      0.80      1000
# weighted avg       0.81      0.80      0.80      1000

# %%
# %% ── APPROACH 2 : VGG16 End-to-End (كامل في cell واحدة) ──────────────────

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time

import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.datasets import cifar10

from sklearn.metrics import (accuracy_score, precision_score, recall_score,
                              f1_score, confusion_matrix, classification_report)
from sklearn.model_selection import train_test_split

# ── Settings ────────────────────────────────────────────────────────────────
CLASS_NAMES    = ['airplane','automobile','bird','cat','deer',
                  'dog','frog','horse','ship','truck']
NUM_CLASSES    = 10
TARGET_SIZE    = (224, 224)
SUBSET_TRAIN   = 5000   # None = كل الداتا (بيحتاج RAM كتير)
SUBSET_TEST    = 1000
LEARNING_RATE  = 1e-4
BATCH_SIZE     = 32
EPOCHS         = 20
DROPOUT_RATE   = 0.5

# ── Load & Resize Data ───────────────────────────────────────────────────────
(X_train_raw, y_train_raw), (X_test_raw, y_test_raw) = cifar10.load_data()
y_train_raw = y_train_raw.flatten()
y_test_raw  = y_test_raw.flatten()

def resize_dataset(X, y, n_samples=None):
    if n_samples:
        idx = np.random.choice(len(X), n_samples, replace=False)
        X, y = X[idx], y[idx]
    X_resized = tf.image.resize(X, TARGET_SIZE).numpy()
    return preprocess_input(X_resized), y

print("Resizing train …")
X_train, y_train = resize_dataset(X_train_raw, y_train_raw, SUBSET_TRAIN)
print("Resizing test  …")
X_test,  y_test  = resize_dataset(X_test_raw,  y_test_raw,  SUBSET_TEST)

# ── Train / Val Split ────────────────────────────────────────────────────────
X_tr, X_val, y_tr, y_val = train_test_split(
    X_train, y_train, test_size=0.20, stratify=y_train, random_state=42)

y_tr_oh  = to_categorical(y_tr,  NUM_CLASSES)
y_val_oh = to_categorical(y_val, NUM_CLASSES)

print(f"Train:{X_tr.shape[0]}  Val:{X_val.shape[0]}  Test:{X_test.shape[0]}")

# ── Augmentation ─────────────────────────────────────────────────────────────
augmentor = ImageDataGenerator(
    rotation_range=15, width_shift_range=0.1, height_shift_range=0.1,
    horizontal_flip=True, zoom_range=0.1, fill_mode='nearest')

# ── Build Model ───────────────────────────────────────────────────────────────
base = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
for layer in base.layers:
    layer.trainable = False

e2e_model = Sequential([
    base,
    GlobalAveragePooling2D(),
    Dense(256, activation='relu'),
    Dropout(DROPOUT_RATE),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(NUM_CLASSES, activation='softmax')
], name='VGG16_EndToEnd')

e2e_model.compile(
    optimizer=Adam(learning_rate=LEARNING_RATE),
    loss='categorical_crossentropy',
    metrics=['accuracy'])

e2e_model.summary()

# ── Train ─────────────────────────────────────────────────────────────────────
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6, verbose=1)]

train_gen = augmentor.flow(X_tr, y_tr_oh, batch_size=BATCH_SIZE, shuffle=True)

print(f"\nTraining up to {EPOCHS} epochs …")
t0 = time.time()
history = e2e_model.fit(
    train_gen,
    steps_per_epoch=len(X_tr) // BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=(X_val, y_val_oh),
    callbacks=callbacks,
    verbose=1)
e2e_train_time = time.time() - t0
print(f"\nDone in {e2e_train_time:.1f}s ({e2e_train_time/60:.1f} min)")

# ── Learning Curves ───────────────────────────────────────────────────────────
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
ep = range(1, len(history.history['accuracy']) + 1)
ax1.plot(ep, history.history['accuracy'],     'b-o', label='Train')
ax1.plot(ep, history.history['val_accuracy'], 'r-s', label='Val')
ax1.set_title('Accuracy', fontweight='bold'); ax1.legend(); ax1.grid(True)
ax2.plot(ep, history.history['loss'],     'b-o', label='Train')
ax2.plot(ep, history.history['val_loss'], 'r-s', label='Val')
ax2.set_title('Loss', fontweight='bold'); ax2.legend(); ax2.grid(True)
plt.tight_layout()
plt.savefig('learning_curves_e2e.png', dpi=150, bbox_inches='tight')
plt.show()

# ── Evaluate ──────────────────────────────────────────────────────────────────
y_pred_e2e = np.argmax(e2e_model.predict(X_test, verbose=0), axis=1)

acc_e2e  = accuracy_score(y_test, y_pred_e2e)
prec_e2e = precision_score(y_test, y_pred_e2e, average='macro')
rec_e2e  = recall_score(y_test, y_pred_e2e, average='macro')
f1_e2e   = f1_score(y_test, y_pred_e2e, average='macro')
cm_e2e   = confusion_matrix(y_test, y_pred_e2e)

print(f"\n── Approach 2 Results ─────────────────────────")
print(f"  Accuracy  : {acc_e2e*100:.2f}%")
print(f"  Precision : {prec_e2e*100:.2f}%")
print(f"  Recall    : {rec_e2e*100:.2f}%")
print(f"  F1-Score  : {f1_e2e*100:.2f}%")
print(f"  Time      : {e2e_train_time:.1f}s")

plt.figure(figsize=(10, 8))
sns.heatmap(cm_e2e, annot=True, fmt='d', cmap='Greens',
            xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES)
plt.title('Confusion Matrix – Approach 2: VGG16 End-to-End',
          fontsize=13, fontweight='bold')
plt.xlabel('Predicted'); plt.ylabel('True')
plt.tight_layout()
plt.savefig('cm_approach2_e2e.png', dpi=150, bbox_inches='tight')
plt.show()
print(classification_report(y_test, y_pred_e2e, target_names=CLASS_NAMES))
# Out:
# Resizing train …
# Resizing test  …
# Train:4000  Val:1000  Test:1000
# Model: "VGG16_EndToEnd"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 7, 7, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,880,202 (56.76 MB)
#  Trainable params: 165,514 (646.54 KB)
#  Non-trainable params: 14,714,688 (56.13 MB)
# Training up to 20 epochs …
# Epoch 1/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 75s 480ms/step - accuracy: 0.1497 - loss: 3.6105 - val_accuracy: 0.3950 - val_loss: 1.7497 - learning_rate: 1.0000e-04
# Epoch 2/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 63s 441ms/step - accuracy: 0.2412 - loss: 2.3589 - val_accuracy: 0.4950 - val_loss: 1.5188 - learning_rate: 1.0000e-04
# Epoch 3/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 55s 442ms/step - accuracy: 0.3220 - loss: 1.9922 - val_accuracy: 0.5700 - val_loss: 1.3554 - learning_rate: 1.0000e-04
# Epoch 4/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 54s 431ms/step - accuracy: 0.3850 - loss: 1.7640 - val_accuracy: 0.6000 - val_loss: 1.2317 - learning_rate: 1.0000e-04
# Epoch 5/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 54s 434ms/step - accuracy: 0.4260 - loss: 1.6342 - val_accuracy: 0.6250 - val_loss: 1.1403 - learning_rate: 1.0000e-04
# Epoch 6/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 55s 440ms/step - accuracy: 0.4775 - loss: 1.5124 - val_accuracy: 0.6490 - val_loss: 1.0674 - learning_rate: 1.0000e-04
# Epoch 7/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 54s 432ms/step - accuracy: 0.4925 - loss: 1.4384 - val_accuracy: 0.6580 - val_loss: 1.0116 - learning_rate: 1.0000e-04
# Epoch 8/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 54s 434ms/step - accuracy: 0.5255 - loss: 1.3533 - val_accuracy: 0.6890 - val_loss: 0.9584 - learning_rate: 1.0000e-04
# Epoch 9/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 54s 435ms/step - accuracy: 0.5585 - loss: 1.2460 - val_accuracy: 0.6880 - val_loss: 0.9070 - learning_rate: 1.0000e-04
# Epoch 10/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 54s 432ms/step - accuracy: 0.5748 - loss: 1.2098 - val_accuracy: 0.7080 - val_loss: 0.8687 - learning_rate: 1.0000e-04
# Epoch 11/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 54s 433ms/step - accuracy: 0.5913 - loss: 1.1685 - val_accuracy: 0.7190 - val_loss: 0.8441 - learning_rate: 1.0000e-04
# Epoch 12/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 54s 433ms/step - accuracy: 0.6093 - loss: 1.1496 - val_accuracy: 0.7160 - val_loss: 0.8271 - learning_rate: 1.0000e-04
# Epoch 13/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 54s 427ms/step - accuracy: 0.6267 - loss: 1.0695 - val_accuracy: 0.7280 - val_loss: 0.8028 - learning_rate: 1.0000e-04
# Epoch 14/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 55s 436ms/step - accuracy: 0.6348 - loss: 1.0567 - val_accuracy: 0.7370 - val_loss: 0.7833 - learning_rate: 1.0000e-04
# Epoch 15/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 54s 435ms/step - accuracy: 0.6388 - loss: 1.0192 - val_accuracy: 0.7480 - val_loss: 0.7634 - learning_rate: 1.0000e-04
# Epoch 16/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 54s 429ms/step - accuracy: 0.6585 - loss: 0.9927 - val_accuracy: 0.7540 - val_loss: 0.7479 - learning_rate: 1.0000e-04
# Epoch 17/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 55s 440ms/step - accuracy: 0.6697 - loss: 0.9482 - val_accuracy: 0.7610 - val_loss: 0.7311 - learning_rate: 1.0000e-04
# Epoch 18/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 55s 436ms/step - accuracy: 0.6783 - loss: 0.9257 - val_accuracy: 0.7610 - val_loss: 0.7191 - learning_rate: 1.0000e-04
# Epoch 19/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 82s 434ms/step - accuracy: 0.6760 - loss: 0.9167 - val_accuracy: 0.7660 - val_loss: 0.7113 - learning_rate: 1.0000e-04
# Epoch 20/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 55s 436ms/step - accuracy: 0.6892 - loss: 0.8916 - val_accuracy: 0.7630 - val_loss: 0.7079 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 20.
#
# Done in 1145.4s (19.1 min)
# ── Approach 2 Results ─────────────────────────
#   Accuracy  : 77.90%
#   Precision : 78.67%
#   Recall    : 77.27%
#   F1-Score  : 77.25%
#   Time      : 1145.4s
#               precision    recall  f1-score   support
#
#     airplane       0.87      0.82      0.85        91
#   automobile       0.93      0.74      0.82       117
#         bird       0.79      0.67      0.73        97
#          cat       0.67      0.58      0.62        91
#         deer       0.66      0.83      0.74        96
#          dog       0.71      0.67      0.69        94
#         frog       0.71      0.92      0.80       106
#        horse       0.91      0.64      0.75        90
#         ship       0.84      0.93      0.88       110
#        truck       0.78      0.92      0.84       108
#
#     accuracy                           0.78      1000
#    macro avg       0.79      0.77      0.77      1000
# weighted avg       0.79      0.78      0.78      1000

# %%
# %% ── CELL 10a : Comparative Bar Chart ──────────────────────────────────────
import numpy as np
import matplotlib.pyplot as plt

acc_svm  = 0.8020 ; prec_svm = 0.8049 ; rec_svm  = 0.8038 ; f1_svm  = 0.8023
acc_e2e  = 0.7790 ; prec_e2e = 0.7867 ; rec_e2e  = 0.7727 ; f1_e2e  = 0.7725

metrics  = ['Accuracy', 'Precision', 'Recall', 'F1-Score']
vals_svm = [acc_svm, prec_svm, rec_svm, f1_svm]
vals_e2e = [acc_e2e, prec_e2e, rec_e2e, f1_e2e]

x, width = np.arange(len(metrics)), 0.35
fig, ax  = plt.subplots(figsize=(10, 6))
b1 = ax.bar(x - width/2, [v*100 for v in vals_svm], width,
            label='Approach 1: VGG16 + SVM',      color='steelblue',  edgecolor='white')
b2 = ax.bar(x + width/2, [v*100 for v in vals_e2e], width,
            label='Approach 2: VGG16 End-to-End', color='darkorange', edgecolor='white')
ax.set_xlabel('Metric', fontsize=12); ax.set_ylabel('Score (%)', fontsize=12)
ax.set_title('Comparative Analysis – Approach 1 vs Approach 2', fontsize=14, fontweight='bold')
ax.set_xticks(x); ax.set_xticklabels(metrics, fontsize=11)
ax.set_ylim(0, 110); ax.legend(fontsize=11); ax.grid(axis='y', alpha=0.4)
for bar in list(b1) + list(b2):
    ax.annotate(f'{bar.get_height():.1f}%',
                xy=(bar.get_x() + bar.get_width()/2, bar.get_height()),
                xytext=(0, 4), textcoords='offset points', ha='center', fontsize=9)
plt.tight_layout()
plt.savefig('comparison_bar_chart.png', dpi=150, bbox_inches='tight')
plt.show()
print("✅ saved → comparison_bar_chart.png")
# Out:
# ✅ saved → comparison_bar_chart.png

# %%
# %% ── CELL 10b : Summary Table ───────────────────────────────────────────────
import pandas as pd

acc_svm  = 0.8020 ; prec_svm = 0.8049 ; rec_svm  = 0.8038 ; f1_svm  = 0.8023
acc_e2e  = 0.7790 ; prec_e2e = 0.7867 ; rec_e2e  = 0.7727 ; f1_e2e  = 0.7725
svm_train_time = 18.3
e2e_train_time = 1145.4

metrics  = ['Accuracy', 'Precision', 'Recall', 'F1-Score']
vals_svm = [acc_svm, prec_svm, rec_svm, f1_svm]
vals_e2e = [acc_e2e, prec_e2e, rec_e2e, f1_e2e]

summary = pd.DataFrame({
    'Metric'                   : metrics + ['Training Time (s)'],
    'Approach 1 (VGG16 + SVM)' : [f'{v*100:.2f}%' for v in vals_svm] + [f'{svm_train_time:.1f}s'],
    'Approach 2 (VGG16 E2E)'   : [f'{v*100:.2f}%' for v in vals_e2e] + [f'{e2e_train_time:.1f}s'],
})
print('='*65)
print('              FINAL COMPARISON SUMMARY')
print('='*65)
print(summary.to_string(index=False))
print('='*65)
# Out:
# =================================================================
#               FINAL COMPARISON SUMMARY
# =================================================================
#            Metric Approach 1 (VGG16 + SVM) Approach 2 (VGG16 E2E)
#          Accuracy                   80.20%                 77.90%
#         Precision                   80.49%                 78.67%
#            Recall                   80.38%                 77.27%
#          F1-Score                   80.23%                 77.25%
# Training Time (s)                    18.3s                1145.4s
# =================================================================

# %%
# %% ── CELL 11 : Hyperparameter Table ────────────────────────────────────────
import pandas as pd

hp = pd.DataFrame([
    ['VGG16 End-to-End', 'Learning Rate',    '0.0001'],
    ['VGG16 End-to-End', 'Batch Size',        '32'],
    ['VGG16 End-to-End', 'Max Epochs',        '20'],
    ['VGG16 End-to-End', 'Optimizer',         'Adam'],
    ['VGG16 End-to-End', 'Loss',              'Categorical Cross-Entropy'],
    ['VGG16 End-to-End', 'Dropout',           '0.5'],
    ['VGG16 End-to-End', 'Early Stopping',    'patience=5'],
    ['SVM Classifier',   'Kernel',            'linear'],
    ['SVM Classifier',   'C',                 '1.0'],
    ['SVM Classifier',   'Feature Reduction', 'PCA (95% variance)'],
    ['SVM Classifier',   'Feature Scaling',   'StandardScaler'],
], columns=['Model', 'Hyperparameter', 'Value'])

print(hp.to_string(index=False))
# Out:
#            Model    Hyperparameter                     Value
# VGG16 End-to-End     Learning Rate                    0.0001
# VGG16 End-to-End        Batch Size                        32
# VGG16 End-to-End        Max Epochs                        20
# VGG16 End-to-End         Optimizer                      Adam
# VGG16 End-to-End              Loss Categorical Cross-Entropy
# VGG16 End-to-End           Dropout                       0.5
# VGG16 End-to-End    Early Stopping                patience=5
#   SVM Classifier            Kernel                    linear
#   SVM Classifier                 C                       1.0
#   SVM Classifier Feature Reduction        PCA (95% variance)
#   SVM Classifier   Feature Scaling            StandardScaler

# %%
# %% ── CELL 12 : Save Results to JSON ────────────────────────────────────────
import json

results = {
    'dataset': 'CIFAR-10', 'model': 'VGG16',
    'approach_1_svm': {
        'accuracy' : 0.8020,
        'precision': 0.8049,
        'recall'   : 0.8038,
        'f1'       : 0.8023,
        'train_time_s': 18.3
    },
    'approach_2_e2e': {
        'accuracy' : 0.7790,
        'precision': 0.7867,
        'recall'   : 0.7727,
        'f1'       : 0.7725,
        'train_time_s': 1145.4
    }
}

with open('project_results.json', 'w') as f:
    json.dump(results, f, indent=2)

print(json.dumps(results, indent=2))
print("\n✅ saved → project_results.json")
# Out:
# {
#   "dataset": "CIFAR-10",
#   "model": "VGG16",
#   "approach_1_svm": {
#     "accuracy": 0.802,
#     "precision": 0.8049,
#     "recall": 0.8038,
#     "f1": 0.8023,
#     "train_time_s": 18.3
#   },
#   "approach_2_e2e": {
#     "accuracy": 0.779,
#     "precision": 0.7867,
#     "recall": 0.7727,
#     "f1": 0.7725,
#     "train_time_s": 1145.4
#   }
# }
#
# ✅ saved → project_results.json
